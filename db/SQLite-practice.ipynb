# %%
import sqlite3
import tkinter as tk
from tkinter import ttk
from tkinter import messagebox
import pandas as pd
from datetime import datetime
from tkcalendar import DateEntry

# %%
conn = sqlite3.connect('data.db')
query = "SELECT * FROM results"
df = pd.read_sql_query(query, conn)
# conn.close()

# %%
df
# Out:
#    id         nume_proba        seria   analiza solicitant     aparat  \
# 0   1  Spirulina 1000 mg    001022024  Proteina         CC   Kjeldhal
# 1   2    spirulina 500mg    006062024  proteina         CC   Kjeldhal
# 2   3   spirulina 500 mg    111111111  proteina         CC    Khedhal
# 3   4             aaaaaa      1111111     rrrrr        ccc    asafasf
# 4   5           offfffff     22222222         3      ccccc  asdasdasf
# 5   6          proteina5  22222222222  proteina         CC   Kheldahl
#
#   data_intrare data_eliberare     utilizator    rezultat
# 0   2024-03-20     2024-03-29  Mihaela Neagu  Corespunde
# 1   2024-06-25     2024-06-28  Mihaela Neagu  corespunde
# 2   2024-06-25     2024-06-28  Mihaela Neagu  corespunde
# 3   2024-06-26     2024-06-26           asfa     asfasfa
# 4   2024-07-03     2024-07-26       asdasafs          nu
# 5   2024-08-06     2024-08-06             MN  corespunde

# %%
f = pd.read_csv('formate-scurt.csv')

# %%
f.aparat[20]
# Out:
# 'UV VIS'

# %%
f.columns
# Out:
# Index(['Format', 'registru', 'aparat', 'Nr. crt.', 'Data', 'Produs',
#        'Serie/Lot', 'val1', 'val2', 'operator', 'stare', 'obs'],
#       dtype='object')

# %%
for i in range(23):
    #print(f.loc[i,f.loc[i,:]!='-'].values)
    header = pd.DataFrame(columns = f.loc[i,f.loc[i,:]!='-'].to_list(), index=range(0))
    #print(header)
    #header.to_csv(f'{i}.csv', index=False, header=True)

# %%
reg = [pd.read_csv(f'registre/{i}.csv') for i in range(23)]

# %%
max([len(reg[i].columns) for i in range(len(reg))])
# Out:
# 12

# %%
listoflists = [list(reg[i].columns) for i in range(len(reg))]

# %%
listoflists[0]
# Out:
# ['432.0',
#  'Registru operare, verificare, calibrare  şi curăţare al balanței analitice',
#  'Balanta Mettler Toledo AB204-S',
#  'Nr. crt.',
#  'Data',
#  'Operaţia/Denumirea probei',
#  'Serie/Lot',
#  'Masa cântărită, g',
#  'Semnătura persoanei care a efectuat operaţia',
#  'Observaţii']

# %%
['-'] * 3 + ['-']
# Out:
# ['-', '-', '-', '-']

# %%
lol_full = [listoflists[i] + ['-'] * (12 - len(listoflists[i])) for i in range(len(reg))]

# %%
headers_df = pd.DataFrame(lol_full, columns=list('abcdefghijkl'))

# %%
headers_df
# Out:
#         a                                                  b  \
# 0   432.0  Registru operare, verificare, calibrare  şi cu...
# 1   432.0  Registru operare, verificare, calibrare  şi cu...
# 2   432.0  Registru operare, verificare, calibrare  şi cu...
# 3   432.0  Registru operare, verificare, calibrare  şi cu...
# 4   271.0                    REGISTRU DE OPERARE ȘI CURĂȚARE
# 5   392.0                                   Registru operare
# 6   563.0                    REGISTRU DE OPERARE ȘI CURĂȚARE
# 7   560.0                    REGISTRU DE OPERARE ȘI CURĂȚARE
# 8   566.0                    REGISTRU DE OPERARE ȘI CURĂȚARE
# 9    73.0                    REGISTRU DE OPERARE ȘI CURĂȚARE
# 10  217.0                     Registru utilizare si curatare
# 11  567.0                    REGISTRU DE OPERARE ȘI CURĂȚARE
# 12  218.0                    REGISTRU DE OPERARE ȘI CURĂȚARE
# 13  559.0                    REGISTRU DE OPERARE ȘI CURĂȚARE
# 14  266.0                    REGISTRU DE OPERARE ȘI CURĂȚARE
# 15  570.0                    REGISTRU DE OPERARE ȘI CURĂȚARE
# 16  600.0                    REGISTRU DE OPERARE ȘI CURĂȚARE
# 17  599.0                    REGISTRU DE OPERARE ȘI CURĂȚARE
# 18  596.0                    REGISTRU DE OPERARE ȘI CURĂȚARE
# 19      0                    REGISTRU DE OPERARE ȘI CURĂȚARE
# 20      0                    REGISTRU DE OPERARE ȘI CURĂȚARE
# 21      0                                  Registru evidenta
# 22     44                                  Registru evidenta
#
#                                                  c                      d  \
# 0                   Balanta Mettler Toledo AB204-S               Nr. crt.
# 1               Balanta Radwag – Partner PS4500 R2               Nr. crt.
# 2                             Balanta VWR 611-2271               Nr. crt.
# 3                        Balanta Partner AS 310 R2               Nr. crt.
# 4                       Balanţa termica VWR MB 160               Nr. crt.
# 5                   Cuptor de calcinare Nabertherm               Nr. crt.
# 6                 Centrifuga Ortoalesa Digiden 21R                   Data
# 7                           Centrifuga Sigma 2-16P                   Data
# 8                             Etuva Memmert UN 110               Nr. crt.
# 9    Sistem de dozare a proteinei Kjeldahl - Buchi               Nr. crt.
# 10                        Incubator Biosan ES - 20               Nr. crt.
# 11               Liofilizator Cool Safe Model 55-4               Nr. crt.
# 12           PH-metru Consort si Seven Copact S210                   Data
# 13            Evaporator Rotativ IKA RV 10 Control                   Data
# 14                           Aparatul Soxhlet VELP               Nr. crt.
# 15            Vascozimetru Fungilab model Expert R                   Data
# 16           Extractor cu ultrasunete Steel 500-DG               Nr. crt.
# 17  Echipament determinare activitate apa Novasina               Nr. crt.
# 18                          Moara cu cutite Gm 200               Nr. crt.
# 19                                            HPLC               Nr. crt.
# 20                                          UV VIS               Nr. crt.
# 21                                           Probe                    Nr.
# 22                             Rapoarte de analiza  Nr. raport de analiză
#
#                        e                                      f  \
# 0                   Data              Operaţia/Denumirea probei
# 1                   Data              Operaţia/Denumirea probei
# 2                   Data              Operaţia/Denumirea probei
# 3                   Data              Operaţia/Denumirea probei
# 4                   Data                               Operaţia
# 5                   Data              Operaţia/Denumirea probei
# 6         Denumire probă                       Tipul probei/Lot
# 7         Denumire probă                       Tipul probei/Lot
# 8                   Data                        Tipul operaţiei
# 9                   Data                      Denumire operaţie
# 10                  Data                               Operaţia
# 11                  Data                      Denumire operaţie
# 12       Denumire produs                              Serie/Lot
# 13        Denumire probă                       Tipul probei/Lot
# 14                  Data                  Denumire probă/Produs
# 15    Denumire probă/Lot                       Vâscozitate (cP)
# 16                  Data              Operaţia/Denumirea probei
# 17                  Data              Operaţia/Denumirea probei
# 18                  Data              Operaţia/Denumirea probei
# 19                  Data                        Denumire produs
# 20                  Data                        Denumire produs
# 21        Denumire probă                                  Seria
# 22  Data primirii probei  Data eliberării raportului de analiză
#
#                                             g  \
# 0                                   Serie/Lot
# 1                                   Serie/Lot
# 2                                   Serie/Lot
# 3                                   Serie/Lot
# 4                        Denumire probă/Serie
# 5                                   Serie/Lot
# 6                        Timp de centrifugare
# 7                        Timp de centrifugare
# 8                 Temperatura de operare (°C)
# 9    Denumire produs, Seria, Data fabricației
# 10                               Staus aparat
# 11  Denumire produs/Seria și data fabricației
# 12                               Tipul probei
# 13                          Timp de evaporare
# 14                           Tipul probei/Lot
# 15                              Timp de lucru
# 16                                  Serie/Lot
# 17                                  Serie/Lot
# 18                                  Serie/Lot
# 19                  Seria și data fabricației
# 20                                  Serie/Lot
# 21                                 Solicitant
# 22                            Denumire produs
#
#                                        h  \
# 0                      Masa cântărită, g
# 1                      Masa cântărită, g
# 2                      Masa cântărită, g
# 3                      Masa cântărită, g
# 4                   Semnătura utilizator
# 5                 Temperatură ºC/ Durata
# 6                                    RPM
# 7                                    RPM
# 8                        Denumire produs
# 9                  Efectuat de/Semnătura
# 10                  Semnătura utilizator
# 11           Efectuat operarea/Semnătura
# 12                         pH determinat
# 13                    Semnătura operator
# 14                      Solvent utilizat
# 15                                  Axul
# 16  Timp de extracție/Putere ultrasunete
# 17     Valoarea activității apei cititie
# 18              Nume și prenume operator
# 19                 Efectuat determinarea
# 20                          Tipul probei
# 21                    Analiza solicitată
# 22                                 Serie
#
#                                                     i  \
# 0        Semnătura persoanei care a efectuat operaţia
# 1        Semnătura persoanei care a efectuat operaţia
# 2        Semnătura persoanei care a efectuat operaţia
# 3        Semnătura persoanei care a efectuat operaţia
# 4                                          Observaţii
# 5   Nume și prenume persoana care a efectuat operația
# 6                                  Semnătura operator
# 7                                  Semnătura operator
# 8                                           Serie/Lot
# 9               Starea aparatului la finalul operării
# 10                                         Observații
# 11              Starea aparatului la finalul operării
# 12                 Efectuat determinarea si curățarea
# 13                                         Observaţii
# 14                                          Semnătura
# 15                                 Semnătura operator
# 16                           Nume și prenume operator
# 17                           Nume și prenume operator
# 18                                         Observaţii
# 19              Starea aparatului la finalul operării
# 20                        Absorbanța/Lungimea de undă
# 21                                      Data primirii
# 22                                          Rezoluție
#
#                                                 j  \
# 0                                      Observaţii
# 1                                      Observaţii
# 2                                      Observaţii
# 3                                      Observaţii
# 4                                               -
# 5                                      Observaţii
# 6                                      Observaţii
# 7                   Curățarea/Statusul aparatului
# 8   Semnătura persoanei care a efectuat  operaţia
# 9                                               -
# 10                                              -
# 11                                              -
# 12          Starea aparatului la finalul operării
# 13                                              -
# 14                                     Observaţii
# 15                   Curățare/Statusul aparatului
# 16                                     Observaţii
# 17                                     Observaţii
# 18                                              -
# 19                                              -
# 20                               Efectuat citirea
# 21                                Data eliberării
# 22                                      Semnătura
#
#                                         k          l
# 0                                       -          -
# 1                                       -          -
# 2                                       -          -
# 3                                       -          -
# 4                                       -          -
# 5                                       -          -
# 6                                       -          -
# 7                              Observaţii          -
# 8                              Observaţii          -
# 9                                       -          -
# 10                                      -          -
# 11                                      -          -
# 12                                      -          -
# 13                                      -          -
# 14                                      -          -
# 15                             Observaţii          -
# 16                                      -          -
# 17                                      -          -
# 18                                      -          -
# 19                                      -          -
# 20  Starea aparatului la finalul operării          -
# 21                                   Nume  Semnătura
# 22                                      -          -

# %%
headers_df.to_csv('headers.csv', index=False, header=True)
