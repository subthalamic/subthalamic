# %%
import numpy as np
from sympy import *

# %%
x, y, z, mu, N, k = symbols('x y z mu N k')

# %%
init_printing()

# %%
X = IndexedBase('X')

# %%
sqrt(Sum((X[k]-mu)**2, (k,1,N))/(N-1))
# Out:
#            ____________________
#           ╱   N
#          ╱   ___
#         ╱    ╲
#        ╱      ╲              2
#       ╱       ╱   (-μ + X[k])
#      ╱       ╱
#     ╱        ‾‾‾
#    ╱        k = 1
#   ╱         ──────────────────
# ╲╱                N - 1

# %%
plot(Sum(sin(x*k)/k, (k,1,10)))
# Out:
# C:\Users\THW\Desktop\pycproj\STATS\venv\lib\site-packages\sympy\plotting\experimental_lambdify.py:188: UserWarning: The evaluation of the expression is problematic. We are trying a failback method that may still work. Please report this as a bug.
#   return self.__call__(args)

# %%
(5+2j).imag
# Out:
# 2.0

# %%
E ** (pi*1j)
# Out:
#  1.0⋅ⅈ⋅π
# ℯ

# %%
solve(E ** (pi*1j) - x, x)
# Out:
# [-1.0]

# %%
solve(x**4+x**3+x**2+x+1, x)
# Out:
# ⎡                 ________                   ________                   ______
# ⎢  1   √5        ╱ √5   5     1   √5        ╱ √5   5     √5   1        ╱ 5   √
# ⎢- ─ + ── - ⅈ⋅  ╱  ── + ─ , - ─ + ── + ⅈ⋅  ╱  ── + ─ , - ── - ─ - ⅈ⋅  ╱  ─ - ─
# ⎣  4   4      ╲╱   8    8     4   4      ╲╱   8    8     4    4     ╲╱   8   8
#
# __                   ________⎤
# 5     √5   1        ╱ 5   √5 ⎥
# ─ , - ── - ─ + ⅈ⋅  ╱  ─ - ── ⎥
#       4    4     ╲╱   8   8  ⎦

# %%
limit(factorial(x)/(x**x), x, oo)
# Out:
# 0

# %%
integrate(1/x,x)
# Out:
# log(x)
