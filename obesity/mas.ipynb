# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as st
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42

# %%
m = pd.read_csv("measurements.csv")
a = pd.read_csv("aeroscan.csv")
s = pd.read_csv("spirometrie.csv")

# %%
m.columns
# Out:
# Index(['ID', 'group', 'sex', 'birth_year', 'chol_init', 'chol_final',
#        'trig_init', 'trig_final', 'weight_init', 'weight_final', 'weight_diff',
#        'height_init', 'height_final', 'height_diff', 'armspan_init',
#        'armspan_final', 'armspan_diff', 'arm_perimeter_init',
#        'arm_periemter_final', 'arm_perimeter_diff', 'thorax_perimeter_init',
#        'thorax_perimeter_final', 'thorax_perimeter_diff',
#        'abdominal_perimeter_init', 'abdominal_perimeter_final',
#        'abdominal_perimeter_diff', 'hip_perimeter_init', 'hip_perimeter_final',
#        'hip_perimeter_diff', 'BMI_init', 'BMI_final', 'BMI_diff',
#        'tricipital_fold_final', 'tricipital_fold_init', 'abdominal_fold_final',
#        'abdominal_fold_init', 'subscapular_fold_final',
#        'subscapular_fold_init'],
#       dtype='object')

# %%
# Out:
#                                   39         40
# ID                               t40         c1
# group                           Test    Control
# sex                                f          m
# birth_year                    2011.0        NaN
# chol_init                      186.0        NaN
# chol_final                     181.0        NaN
# trig_init                       88.0        NaN
# trig_final                      83.0        NaN
# weight_init                     55.4       63.4
# weight_final                    54.3       70.1
# weight_diff                     -1.1        6.7
# height_init                      145        158
# height_final                   151.0      165.0
# height_diff                      6.0        7.0
# armspan_init                   147.0      162.0
# armspan_final                    153        169
# armspan_diff                     6.0        7.0
# arm_perimeter_init                24         25
# arm_periemter_final               27         27
# arm_perimeter_diff                 3          2
# thorax_perimeter_init             74         58
# thorax_perimeter_final            85         70
# thorax_perimeter_diff             11         12
# abdominal_perimeter_init        76.0       84.0
# abdominal_perimeter_final         78         86
# abdominal_perimeter_diff         2.0        2.0
# hip_perimeter_init                82         94
# hip_perimeter_final               85         95
# hip_perimeter_diff                 3          1
# BMI_init                   26.349584  25.396571
# BMI_final                  23.814745  25.748393
# BMI_diff                   -2.534839   0.351822
# tricipital_fold_final           10.0        NaN
# tricipital_fold_init            39.0        NaN
# abdominal_fold_final            16.0        NaN
# abdominal_fold_init             50.0        NaN
# subscapular_fold_final          18.0        NaN
# subscapular_fold_init           40.0        NaN
