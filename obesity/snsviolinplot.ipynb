# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as stats
from scipy.stats import pearsonr
from scipy.stats import shapiro

# %%
m = pd.read_csv("measurements.csv")

# %%
a = pd.read_csv("aeroscan.csv")

# %%
s = pd.read_csv("spirometrie.csv")

# %%
sns.violinplot(data=m.loc[:,['BMI_init','BMI_final']].melt(var_name='time', value_name='vals'), x='time', y='vals')
# Out:
# <Axes: xlabel='time', ylabel='vals'>

# %%
m.loc[:,['BMI_init','BMI_final']].melt(var_name='time', value_name='vals')
# Out:
#           time       vals
# 0     BMI_init  27.840090
# 1     BMI_init  28.398718
# 2     BMI_init  27.449047
# 3     BMI_init  27.674225
# 4     BMI_init  27.162695
# ..         ...        ...
# 155  BMI_final  24.675500
# 156  BMI_final  25.280110
# 157  BMI_final  24.499860
# 158  BMI_final  24.365610
# 159  BMI_final  27.217303
#
# [160 rows x 2 columns]
